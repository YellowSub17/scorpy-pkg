# %%
# %load_ext autoreload
# %autoreload 2

import scorpy
c = scorpy.CorrelationVol()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Out:
# Help on method copy in module scorpy.vols.base.basevol:
#
# copy() method of scorpy.vols.corr.correlationvol.CorrelationVol instance
#     Generate an independent deep copy of the active volumetric object.
#
#     Returns
#     -------
#     BaseVol
#         A deep copy instance replica containing identical elements.
